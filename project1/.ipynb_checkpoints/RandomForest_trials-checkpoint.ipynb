# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import AllChem
from rdkit.Chem import rdFingerprintGenerator
from rdkit import DataStructs
from rdkit.Chem import MACCSkeys
from rdkit.Chem.Fingerprints import FingerprintMols
import matplotlib.pyplot as plt

from descriptastorus.descriptors.DescriptorGenerator import MakeGenerator
#https://github.com/bp-kelley/descriptastorus

# %%
full_copy = pd.read_csv('../../../project1_data/Series4_workingCopy.csv', index_col = 'ID')
# full_copy.head()

# %%
PandasTools.AddMoleculeColumnToFrame(full_copy,smilesCol='SMILES')
# full_copy.head()

# %% [markdown]
# # Generating descriptors using RDKit

# %%
# RDKit
generator = MakeGenerator(("RDKit2D",))

full_copy_rdkit2d = [generator.process(x)[1:] for x in full_copy['SMILES']]

# %%
rdkit2d_name = []
for name, numpy_type in generator.GetColumns():
    rdkit2d_name.append(name)
    
full_copy_rdkit2d_df = pd.DataFrame(full_copy_rdkit2d, index = full_copy.index, columns=rdkit2d_name[1:])

# %%
# full_copy_rdkit2d_df.head()

# %%
full_copy_rdkit2d_df.to_csv('../../../project1_data/full_copy_rdkit2d_df.csv')

# %%
allMerged = pd.merge(full_copy,full_copy_rdkit2d_df,left_on='ID',right_on='ID')

# %%
allMerged.to_csv('../../../project1_data/full_copy_with_Descriptors.csv')
allMerged
# Out:
#                                               SMILES  desired  clearance  \
# ID
# DDD01830003                 CN1CCN(CC1)c1snc2ccccc12    4.530     21.770
# DDD01830066                CNC1CCN(CC1)c1snc2ccccc12    4.530      2.126
# DDD01865274             CN(C)C1CCN(CC1)c1snc2ccccc12    4.530     20.190
# DDD01865292         CN(C)[C@@H]1CCN(C1)c1snc2ccccc12    4.530     31.440
# DDD01865293          CN(C)[C@H]1CCN(C1)c1snc2ccccc12    4.530     22.060
# ...                                              ...      ...        ...
# DDD02099395         O=C1CCCN1C1CCN(CC1)c1snc2ccccc12    7.566      8.144
# DDD02174695  CC(=O)N[C@@H]1CCCN(C1)c1snc2cccc(c12)Br    7.651        NaN
# DDD02156129       C1CC(CCn2ccnn2)CN(C1)c1snc2ccccc12    7.842     13.000
# DDD01868260    C1C[C@H](CN(C1)c1snc2ccccc12)Cn1ccnc1    8.021      5.992
# DDD02153544       C1CC(CCn2cncn2)CN(C1)c1snc2ccccc12    8.114     16.070
#
#                                                          ROMol  BalabanJ  \
# ID
# DDD01830003  <img data-content="rdkit/molecule" src="data:i...  1.937895
# DDD01830066  <img data-content="rdkit/molecule" src="data:i...  1.848870
# DDD01865274  <img data-content="rdkit/molecule" src="data:i...  1.802626
# DDD01865292  <img data-content="rdkit/molecule" src="data:i...  1.901067
# DDD01865293  <img data-content="rdkit/molecule" src="data:i...  1.901067
# ...                                                        ...       ...
# DDD02099395  <img data-content="rdkit/molecule" src="data:i...  1.485968
# DDD02174695  <img data-content="rdkit/molecule" src="data:i...  1.887323
# DDD02156129  <img data-content="rdkit/molecule" src="data:i...  1.460899
# DDD01868260  <img data-content="rdkit/molecule" src="data:i...  1.547816
# DDD02153544  <img data-content="rdkit/molecule" src="data:i...  1.460899
#
#                 BertzCT       Chi0      Chi0n      Chi0v       Chi1  ...  \
# ID                                                                   ...
# DDD01830003  485.724459  10.957819   9.387717  10.204214   7.843337  ...
# DDD01830066  500.088813  11.664926  10.017854  10.834351   8.381341  ...
# DDD01865274  526.573555  12.535169  10.965068  11.781564   8.754020  ...
# DDD01865292  520.113861  11.828063  10.257961  11.074457   8.254020  ...
# DDD01865293  520.113861  11.828063  10.257961  11.074457   8.254020  ...
# ...                 ...        ...        ...        ...        ...  ...
# DDD02099395  660.340771  14.233840  11.994636  12.811133  10.326500  ...
# DDD02174695  642.380766  14.112520  11.226716  13.629210   9.647867  ...
# DDD02156129  735.926729  14.777810  12.428409  13.244905  10.898979  ...
# DDD01868260  718.799136  14.070703  11.851439  12.667935  10.398979  ...
# DDD02153544  735.926729  14.777810  12.428409  13.244905  10.898979  ...
#
#              fr_sulfonamd  fr_sulfone  fr_term_acetylene  fr_tetrazole  \
# ID
# DDD01830003             0           0                  0             0
# DDD01830066             0           0                  0             0
# DDD01865274             0           0                  0             0
# DDD01865292             0           0                  0             0
# DDD01865293             0           0                  0             0
# ...                   ...         ...                ...           ...
# DDD02099395             0           0                  0             0
# DDD02174695             0           0                  0             0
# DDD02156129             0           0                  0             0
# DDD01868260             0           0                  0             0
# DDD02153544             0           0                  0             0
#
#              fr_thiazole  fr_thiocyan  fr_thiophene  fr_unbrch_alkane  \
# ID
# DDD01830003            0            0             0                 0
# DDD01830066            0            0             0                 0
# DDD01865274            0            0             0                 0
# DDD01865292            0            0             0                 0
# DDD01865293            0            0             0                 0
# ...                  ...          ...           ...               ...
# DDD02099395            0            0             0                 0
# DDD02174695            0            0             0                 0
# DDD02156129            0            0             0                 0
# DDD01868260            0            0             0                 0
# DDD02153544            0            0             0                 0
#
#              fr_urea       qed
# ID
# DDD01830003        0  0.751236
# DDD01830066        0  0.883439
# DDD01865274        0  0.828442
# DDD01865292        0  0.812296
# DDD01865293        0  0.812296
# ...              ...       ...
# DDD02099395        0  0.855565
# DDD02174695        0  0.901188
# DDD02156129        0  0.741927
# DDD01868260        0  0.742856
# DDD02153544        0  0.741927
#
# [331 rows x 204 columns]

# %%
allMerged = pd.read_csv('../../../project1_data/full_copy_with_Descriptors.csv', index_col = 'ID')
allMerged.dropna(inplace=True)
allMerged.drop(allMerged[allMerged.clearance > 49.9].index, inplace=True)
allMerged.drop(allMerged[allMerged.desired < 4.6].index, inplace=True)
allMerged.drop(allMerged[allMerged.clearance < 0.51].index, inplace=True)
# allMerged[allMerged['clearance'] > 49.9 ]
allMerged
# Out:
#                                                         SMILES  desired  \
# ID
# DDD02155729   Cn1cnc(c1)C(=O)N[C@H]1CN(CC[C@H]1F)c1snc2ccccc12    4.616
# DDD01865290                       O[C@@H]1CCN(C1)c1snc2ccccc12    4.652
# DDD02098186                  C1CCN(C1)CC1CCCN(C1)c1snc2ccccc12    4.726
# DDD01865235                        OCCCN1CCN(CC1)c1snc2ccccc12    4.773
# DDD02155687  F[C@@H]1CCN(C[C@@H]1NC(=O)C1CC(=O)C1)c1snc2ccc...    4.781
# ...                                                        ...      ...
# DDD02157535             CC(=O)N[C@@H]1CCCN(C1)c1snc2ccc(cc12)F    7.489
# DDD02099395                   O=C1CCCN1C1CCN(CC1)c1snc2ccccc12    7.566
# DDD02156129                 C1CC(CCn2ccnn2)CN(C1)c1snc2ccccc12    7.842
# DDD01868260              C1C[C@H](CN(C1)c1snc2ccccc12)Cn1ccnc1    8.021
# DDD02153544                 C1CC(CCn2cncn2)CN(C1)c1snc2ccccc12    8.114
#
#              clearance                                              ROMol  \
# ID
# DDD02155729      1.511  <img data-content="rdkit/molecule" src="data:i...
# DDD01865290      2.797  <img data-content="rdkit/molecule" src="data:i...
# DDD02098186     29.870  <img data-content="rdkit/molecule" src="data:i...
# DDD01865235      2.090  <img data-content="rdkit/molecule" src="data:i...
# DDD02155687      2.611  <img data-content="rdkit/molecule" src="data:i...
# ...                ...                                                ...
# DDD02157535      3.926  <img data-content="rdkit/molecule" src="data:i...
# DDD02099395      8.144  <img data-content="rdkit/molecule" src="data:i...
# DDD02156129     13.000  <img data-content="rdkit/molecule" src="data:i...
# DDD01868260      5.992  <img data-content="rdkit/molecule" src="data:i...
# DDD02153544     16.070  <img data-content="rdkit/molecule" src="data:i...
#
#              BalabanJ     BertzCT       Chi0      Chi0n      Chi0v       Chi1  \
# ID
# DDD02155729  1.521438  907.225297  17.388541  13.723438  14.539935  12.114194
# DDD01865290  2.038738  482.147587  10.250712   8.257961   9.074457   7.343337
# DDD02098186  1.492419  602.855957  14.070703  12.500601  13.317098  10.398979
# DDD01865235  1.679665  534.225528  13.079140  10.956251  11.772748   9.381341
# DDD02155687  1.480730  784.988565  16.681434  13.074122  13.890619  11.614194
# ...               ...         ...        ...        ...        ...        ...
# DDD02157535  1.863560  642.380766  14.112520  11.226716  12.043213   9.631030
# DDD02099395  1.485968  660.340771  14.233840  11.994636  12.811133  10.326500
# DDD02156129  1.460899  735.926729  14.777810  12.428409  13.244905  10.898979
# DDD01868260  1.547816  718.799136  14.070703  11.851439  12.667935  10.398979
# DDD02153544  1.460899  735.926729  14.777810  12.428409  13.244905  10.898979
#
#              ...  fr_sulfonamd  fr_sulfone  fr_term_acetylene  fr_tetrazole  \
# ID           ...
# DDD02155729  ...             0           0                  0             0
# DDD01865290  ...             0           0                  0             0
# DDD02098186  ...             0           0                  0             0
# DDD01865235  ...             0           0                  0             0
# DDD02155687  ...             0           0                  0             0
# ...          ...           ...         ...                ...           ...
# DDD02157535  ...             0           0                  0             0
# DDD02099395  ...             0           0                  0             0
# DDD02156129  ...             0           0                  0             0
# DDD01868260  ...             0           0                  0             0
# DDD02153544  ...             0           0                  0             0
#
#              fr_thiazole  fr_thiocyan  fr_thiophene  fr_unbrch_alkane  \
# ID
# DDD02155729            0            0             0                 0
# DDD01865290            0            0             0                 0
# DDD02098186            0            0             0                 0
# DDD01865235            0            0             0                 0
# DDD02155687            0            0             0                 0
# ...                  ...          ...           ...               ...
# DDD02157535            0            0             0                 0
# DDD02099395            0            0             0                 0
# DDD02156129            0            0             0                 0
# DDD01868260            0            0             0                 0
# DDD02153544            0            0             0                 0
#
#              fr_urea       qed
# ID
# DDD02155729        0  0.779891
# DDD01865290        0  0.796688
# DDD02098186        0  0.863134
# DDD01865235        0  0.924860
# DDD02155687        0  0.925488
# ...              ...       ...
# DDD02157535        0  0.925244
# DDD02099395        0  0.855565
# DDD02156129        0  0.741927
# DDD01868260        0  0.742856
# DDD02153544        0  0.741927
#
# [208 rows x 204 columns]

# %%
X_plotting=allMerged.iloc[:, 1].values #desirable data
y_plotting=allMerged.iloc[:, 2].values #clearance
plt.scatter(X_plotting, y_plotting)
m, b = np.polyfit(X_plotting, y_plotting, 1)
plt.plot(X_plotting, m*X_plotting + b)

# %%
allMerged_processed = allMerged.drop(['clearance'], axis=1)
# allMerged_processed = allMerged.drop(['desired'], axis=1)

# %%
allMerged_processed = allMerged_processed.drop(['ROMol'], axis=1)

# %%
allMerged_processed.shape
# Out:
# (208, 202)

# %% [markdown]
# #Random forest

# %%
X = allMerged_processed.iloc[:, 2:,].values #descreptors
y = allMerged_processed.iloc[:, 1].values #desired property
# y

# %%
print(X.shape)
# print(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_test.shape)
# Out:
# (208, 200)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=2000, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print(y_test)
print(y_pred)
# Out:
# Mean Absolute Error: 0.460488117899668
# Mean Squared Error: 0.37119518769907284
# Root Mean Squared Error: 0.609257899168384
# [4.891 5.592 5.139 4.799 6.768 5.609 5.819 5.838 5.651 6.096 5.288 6.105
#  5.338 6.887 5.684 5.632 7.566 5.197 5.434 4.963 6.43  4.906 4.821 5.373
#  5.655 5.896 5.844 5.842 6.178 6.682 5.529 6.028 5.929 5.48  6.728 5.992
#  6.488 5.821 4.927 5.898 6.895 5.01 ]
# [5.93613897 5.51965467 5.53342961 5.88811249 6.12059079 5.52374675
#  5.99609658 5.76932759 5.74567254 5.89535708 5.56261492 5.55342927
#  5.54783782 6.29328859 5.2526393  5.53543671 5.67927096 5.37152402
#  5.95641416 5.32197884 6.12059079 5.74018642 5.91827921 5.75801837
#  5.58622765 6.6005258  6.2923153  5.66226441 5.65537627 6.5914096
#  5.65041231 5.95894452 6.14463167 6.12059079 6.34940178 5.68169575
#  6.82540056 5.57039739 5.69691478 5.70050705 5.55640839 6.10537112]

# %%
###Predicting for the new set of desirable data
validation = pd.read_csv('../../../project1_data/validation.csv', index_col = 'ID')
validation.dropna(inplace=True)
# validation
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-349-476e5fa2f976> in <module>()
#       1 ###Predicting for the new set of desirable data
# ----> 2 validation = pd.read_csv('../../../project1_data/validation.csv', index_col = 'ID')
#       3 validation.dropna(inplace=True)
#       4 # validation
#
# /Users/KHatti001/opt/anaconda3/envs/chem_ml/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /Users/KHatti001/opt/anaconda3/envs/chem_ml/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /Users/KHatti001/opt/anaconda3/envs/chem_ml/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# /Users/KHatti001/opt/anaconda3/envs/chem_ml/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# /Users/KHatti001/opt/anaconda3/envs/chem_ml/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../project1_data/validation.csv'

# %%
X_valid = validation.iloc[:, 2:,].values #descreptors
y_valid = validation.iloc[:, 1].values #desirable data
X_valid.shape
# Out:
# (67, 200)

# %%
Y_valid_pred = regressor.predict(X_valid)
print(Y_valid_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_valid, Y_valid_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_valid, Y_valid_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_valid, Y_valid_pred)))
# Out:
# [5.87170103 5.85636491 5.84370311 5.82860938 5.85642589 5.88699609
#  5.87945608 5.88106323 5.85642589 5.848766   5.88287313 5.85642589
#  5.88809684 5.85010045 5.88215191 5.886967   5.85058983 5.85010045
#  5.88650328 5.87538522 5.85010045 5.85058983 5.87892583 5.88454222
#  5.88346151 5.85991745 5.88106323 5.88237318 5.85636491 5.85051062
#  5.87733807 5.84945383 5.88650328 5.82994409 5.87553453 5.89785492
#  5.84370311 5.88552369 5.88287313 5.89296691 5.8742803  5.88818259
#  5.88287313 5.83287927 5.87883918 5.8894941  5.88650328 5.85636491
#  5.82829786 5.83577336 5.82664574 5.86901304 5.85684154 5.88078023
#  5.84094424 5.87319212 5.87200694 5.83433463 5.85123273 5.86518354
#  5.86371466 5.87605529 5.86619572 5.88681042 5.89323957 5.84370311
#  5.86428295]
# Mean Absolute Error: 0.5951765572672263
# Mean Squared Error: 0.532982467565765
# Root Mean Squared Error: 0.7300564824489711

# %%
from sklearn.metrics import r2_score
plt.scatter(y_test, y_pred)
m, b = np.polyfit(y_test, y_pred, 1)
plt.plot(y_test, m*y_test + b)
# plt.axes.set_title()
# plt.title('R2: ' + str(r2_score(y_test, y_pred)))
# for f in y_pred:
#     print (f)

# %%
plt.scatter(y_valid, Y_valid_pred)
m, b = np.polyfit(y_valid, Y_valid_pred, 1)
plt.plot(y_valid, m*y_valid + b)
# plt.title('R2: ' + str(r2_score(y_valid, Y_valid_pred)))

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.4885241984496014
# Mean Squared Error: 0.367773779643749
# Root Mean Squared Error: 0.6064435502532358
